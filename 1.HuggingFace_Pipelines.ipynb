# %% [markdown]
# # Install the necessary dependencies

# %%
# !pip install transformers torch datasets
# Out:
# Requirement already satisfied: transformers in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (5.3.0)
# Requirement already satisfied: torch in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.10.0+cu130)
# Requirement already satisfied: datasets in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (4.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.12.2)
# Requirement already satisfied: anyio in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.9.0)
# Requirement already satisfied: certifi in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in C:\Users\Piyush\AppData\Roaming\Python\Python312\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.12.10)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Piyush\AppData\Roaming\Python\Python312\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Piyush\AppData\Roaming\Python\Python312\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Piyush\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich>=12.3.0->typer->transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %% [markdown]
# # Set the usage of GPU (Cuda)

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
device = 0 if torch.cuda.is_available() else -1

print(device)
# Out:
# Torch: 2.10.0+cu130
# CUDA available: True
# CUDA version: 13.0
# 0

# %% [markdown]
# # Using the Pipeline API

# %%
from transformers import pipeline

# %%
#View all the availabe tasks for my pipeline version

from transformers.pipelines import PIPELINE_REGISTRY

tasks = PIPELINE_REGISTRY.get_supported_tasks()

for i, task in enumerate(tasks, start=1):
    print(f"{i}. {task}", end='\t')
# Out:
# 1. any-to-any	2. audio-classification	3. automatic-speech-recognition	4. depth-estimation	5. document-question-answering	6. feature-extraction	7. fill-mask	8. image-classification	9. image-feature-extraction	10. image-segmentation	11. image-text-to-text	12. keypoint-matching	13. mask-generation	14. ner	15. object-detection	16. sentiment-analysis	17. table-question-answering	18. text-classification	19. text-generation	20. text-to-audio	21. text-to-speech	22. token-classification	23. video-classification	24. zero-shot-audio-classification	25. zero-shot-classification	26. zero-shot-image-classification	27. zero-shot-object-detection
