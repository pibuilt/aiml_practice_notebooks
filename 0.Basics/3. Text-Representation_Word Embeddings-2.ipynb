# %% [markdown]
# #Word2Vec

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
# !pip install --upgrade gensim --user
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
story = []
for filename in os.listdir('data'):
    if filename == '.ipynb_checkpoints':
      pass
    f = open(os.path.join('data',filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 8602

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (322628, 447775)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('still', 0.9991456270217896),
#  ('then', 0.9991390109062195),
#  ('off', 0.9991376399993896),
#  ('between', 0.9991285800933838),
#  ('deep', 0.999100387096405),
#  ('fire', 0.9990986585617065),
#  ('stone', 0.9990968704223633),
#  ('through', 0.9990878701210022),
#  ('its', 0.9990835785865784),
#  ('blue', 0.9990776181221008)]

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.9997353

# %%
model.wv['deep'].shape
# Out:
# (100,)

# %%
vec = model.wv.get_normed_vectors()

# %%
vec
# Out:
# array([[-0.1128015 ,  0.06839193,  0.1211883 , ..., -0.08533611,
#          0.09456035,  0.02292893],
#        [-0.1077722 ,  0.06837212,  0.11315578, ..., -0.08254499,
#          0.09009724,  0.01294028],
#        [-0.06754793,  0.05043191,  0.08689904, ..., -0.07362028,
#          0.08482575, -0.01962107],
#        ...,
#        [-0.05818678,  0.10843779,  0.11339491, ..., -0.09442885,
#          0.08770828,  0.02115588],
#        [-0.06613204,  0.07905799,  0.06715882, ..., -0.10124326,
#          0.06962094, -0.02799226],
#        [ 0.01544122,  0.12542738, -0.00290807, ..., -0.05728641,
#          0.09407735, -0.02345274]], dtype=float32)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (3840, 100)

# %%
y = model.wv.index_to_key

# %%
len(y)
# Out:
# 3840

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X
# Out:
# array([[-0.00865035, -0.21858332, -0.0012506 ],
#        [-0.02242175, -0.17416269,  0.00394394],
#        [-0.0541345 ,  0.03286046,  0.00052168],
#        ...,
#        [ 0.00613627,  0.04352815, -0.00094838],
#        [-0.02316291, -0.05711579, -0.02663467],
#        [ 0.07312023,  0.13775016,  0.11508474]], dtype=float32)

# %%
X.shape
# Out:
# (3840, 3)
